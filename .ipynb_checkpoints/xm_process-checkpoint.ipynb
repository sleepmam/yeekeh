# %%
#import necessary tools
import re
from string import digits
import pandas as pd
import numpy as np

# %%
#read the documents
with open('209_1.txt','rb') as f:
    contents = f.read()
    contents = contents.decode("utf-16").rstrip("\n")
    contents = contents.split("\r\n") #maybe need to strip \t?

# %%
BlockNum=[]
Procedure=list()
TrialNUM =[] #somehow eprime writes as TrialNUM
img1 =[]
img2=[]
Choice_RESP = []
Choice_RT=[]
#there should be a BL and LB version
#101 is BL, 16 RT, 


#if there is an error message, stop?

for i in range(len(contents)):
    
    if contents[i] == '\t*** LogFrame Start ***' and contents[i+8].startswith("\tListBlack1")==True:
        #black 1
        Procedurea = contents[i+1].split("Procedure: ",1)[1] 
        Procedure.append(Procedurea)        
        
        img1a =contents[i+2].split("img1: ",1)[1] 
        img1.append(img1a)
        
        img2a =contents[i+3].split("img2: ",1)[1] 
        img2.append(img2a)
        
        TrialNUMa =[''.join(c for c in contents[i+4] if c in digits)]
        TrialNUMa = [float(i) for i in TrialNUMa] 
        TrialNUMa = list(TrialNUMa)
        TrialNUM=TrialNUM+TrialNUMa
        
        BlockNuma =[''.join(c for c in contents[i+5] if c in digits)]
        BlockNum=BlockNum+BlockNuma
        
        Choice_RESPa =[''.join(c for c in contents[i+17] if c in digits)]
        Choice_RESP=Choice_RESP+Choice_RESPa
        
        #Choice_RTa =[''.join(c for c in contents[i+16] if c in digits)]
        Choice_RTa = contents[i+16].split("ChoiceB.RT: ",1)[1] 
        if Choice_RTa == [""]:
            break
        print(BlockNum, "and", TrialNUM, "and", Choice_RTa)
        Choice_RTa = [float(i) for i in Choice_RTa]
        Choice_RTa = list(Choice_RTa)
        Choice_RT=Choice_RT+Choice_RTa
        
    elif contents[i] == '\t*** LogFrame Start ***' and contents[i+8].startswith("\tListBlack2")==True:
        #black 2
        Procedurea = contents[i+1].split("Procedure: ",1)[1] 
        Procedure.append(Procedurea)        
        
        img1a =contents[i+2].split("img1: ",1)[1] 
        img1.append(img1a)
        
        img2a =contents[i+3].split("img2: ",1)[1] 
        img2.append(img2a)
        
        TrialNUMa =[''.join(c for c in contents[i+4] if c in digits)]
        TrialNUMa = [float(i) for i in TrialNUMa] 
        TrialNUMa = list(TrialNUMa)
        TrialNUM=TrialNUM+TrialNUMa
        
        BlockNuma =[''.join(c for c in contents[i+5] if c in digits)]
        BlockNum=BlockNum+BlockNuma
        
        Choice_RESPa =[''.join(c for c in contents[i+15] if c in digits)]
        Choice_RESP=Choice_RESP+Choice_RESPa
        
        #Choice_RTa =[''.join(c for c in contents[i+14] if c in digits)]
        print("this is", contents[i+14].split("ChoiceB.RT:"))
        if contents[i+14].split("ChoiceB.RT:",1) == "[*** LogFrame Start ***]":
            break
        Choice_RTa = contents[i+14].split("ChoiceB.RT: ",1)[1] 
        print(BlockNum, "and", TrialNUM, "and", Choice_RTa)
        Choice_RTa = [float(i) for i in Choice_RTa]
        Choice_RTa = list(Choice_RTa)
        Choice_RT=Choice_RT+Choice_RTa
        
    elif contents[i] == '\t*** LogFrame Start ***' and contents[i+8].startswith("\tListLike1")==True:
        #like 1
        Procedurea = contents[i+1].split("Procedure: ",1)[1] 
        Procedure.append(Procedurea)        
        
        img1a =contents[i+2].split("img1: ",1)[1] 
        img1.append(img1a)
        
        img2a =contents[i+3].split("img2: ",1)[1] 
        img2.append(img2a)
        
        TrialNUMa =[''.join(c for c in contents[i+5] if c in digits)]
        TrialNUMa = [float(i) for i in TrialNUMa] 
        TrialNUMa = list(TrialNUMa)
        TrialNUM=TrialNUM+TrialNUMa
        
        BlockNuma =[''.join(c for c in contents[i+6] if c in digits)]
        BlockNum=BlockNum+BlockNuma
        
        Choice_RESPa =[''.join(c for c in contents[i+18] if c in digits)]
        Choice_RESP=Choice_RESP+Choice_RESPa
        
        #Choice_RTa =[''.join(c for c in contents[i+17] if c in digits)]
        Choice_RTa = contents[i+17].split("ChoiceL.RT: ",1)[1] 
        if Choice_RTa == [""]:
            break
        print(BlockNum, "and", TrialNUM, "and", Choice_RTa)
        Choice_RTa = [float(i) for i in Choice_RTa]
        Choice_RTa = list(Choice_RTa)
        Choice_RT=Choice_RT+Choice_RTa
        
    elif contents[i] == '\t*** LogFrame Start ***' and contents[i+8].startswith("\tListLike1")==True:
        #like 2
        Procedurea = contents[i+1].split("Procedure: ",1)[1] 
        Procedure.append(Procedurea)        
        
        img1a =contents[i+2].split("img1: ",1)[1] 
        img1.append(img1a)
        
        img2a =contents[i+3].split("img2: ",1)[1] 
        img2.append(img2a)
        
        TrialNUMa =[''.join(c for c in contents[i+5] if c in digits)]
        TrialNUMa = [float(i) for i in TrialNUMa] 
        TrialNUMa = list(TrialNUMa)
        TrialNUM=TrialNUM+TrialNUMa
        #trial needs to be plus one, the NONE group is also not right yet
        #needs to be (blocknum-1)*50+trial
        
        BlockNuma =[''.join(c for c in contents[i+6] if c in digits)]
        BlockNum=BlockNum+BlockNuma
        
        Choice_RESPa =[''.join(c for c in contents[i+16] if c in digits)]
        Choice_RESP=Choice_RESP+Choice_RESPa
        
        #Choice_RTa =[''.join(c for c in contents[i+15] if c in digits)]
        Choice_RTa = contents[i+15].split("ChoiceL.RT: ",1)[1] 
        if Choice_RTa == [""]:
            break
        print(BlockNum, "and", TrialNUM, "and", Choice_RTa)
        Choice_RTa = [float(i) for i in Choice_RTa]
        Choice_RTa = list(Choice_RTa)
        Choice_RT=Choice_RT+Choice_RTa
        
        
Procedure_df = pd.DataFrame(Procedure)
Procedure_df.columns = ['Btype']  
        
img1 = [int(i) for i in img1] 
img1_df = pd.DataFrame(img1)
img1_df.columns = ['img1']

img2 = [int(i) for i in img2] 
img2_df = pd.DataFrame(img2)
img2_df.columns = ['img2']

TrialNUM = [int(i) for i in TrialNUM] 
TrialNUM_df = pd.DataFrame(TrialNUM)
TrialNUM_df.columns = ['trial']

BlockNum = [int(i) for i in BlockNum] 
BlockNum_df = pd.DataFrame(BlockNum)
BlockNum_df.columns = ['block']

Choice_RESP = [int(i) for i in Choice_RESP] 
Choice_RESP_df = pd.DataFrame(Choice_RESP)
Choice_RESP_df.columns = ['RESP']

Choice_RT = [int(i) for i in Choice_RT] 
Choice_RT_df = pd.DataFrame(Choice_RT)
Choice_RT_df.columns = ['RT']
# Out:
# this is ['\t', ' 1159']
# ['3'] and [51.0] and 1159
# this is ['\t', ' 2435']
# ['3', '3'] and [51.0, 52.0] and 2435
# this is ['\t', ' 1406']
# ['3', '3', '3'] and [51.0, 52.0, 53.0] and 1406
# this is ['\t', ' 1645']
# ['3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0] and 1645
# this is ['\t', ' 1779']
# ['3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0] and 1779
# this is ['\t', ' 804']
# ['3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0] and 804
# this is ['\t', ' 601']
# ['3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0] and 601
# this is ['\t', ' 1135']
# ['3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0] and 1135
# this is ['\t', ' 1072']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0] and 1072
# this is ['\t', ' 2248']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0] and 2248
# this is ['\t', ' 1213']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0] and 1213
# this is ['\t', ' 1169']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0] and 1169
# this is ['\t', ' 595']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0] and 595
# this is ['\t', ' 1094']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0] and 1094
# this is ['\t', ' 1130']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0] and 1130
# this is ['\t', ' 656']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0] and 656
# this is ['\t', ' 1054']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0] and 1054
# this is ['\t', ' 1341']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0] and 1341
# this is ['\t', ' 741']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 69.0] and 741
# this is ['\t', ' 649']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 69.0, 70.0] and 649
# this is ['\t', ' 758']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 69.0, 70.0, 71.0] and 758
# this is ['\t', ' 1294']
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 69.0, 70.0, 71.0, 72.0] and 1294
# this is ['*** LogFrame Start ***']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-72edab801bdd> in <module>
#      71         if contents[i+14].split("ChoiceB.RT:",1) == "[*** LogFrame Start ***]":
#      72             break
# ---> 73         Choice_RTa = contents[i+14].split("ChoiceB.RT: ",1)[1]
#      74         print(BlockNum, "and", TrialNUM, "and", Choice_RTa)
#      75         Choice_RTa = [float(i) for i in Choice_RTa]
#
# IndexError: list index out of range

# %%
sub_id = contents[16].split("Subject: ",1)[1] 
sub_df = pd.DataFrame(np.repeat(sub_id, img1_df.shape[0], axis = 0))
sub_df.columns = ['sub']

all = pd.concat([sub_df.reset_index(drop=True), BlockNum_df], axis=1)
all = pd.concat([all.reset_index(drop=True), Procedure_df], axis=1)
all = pd.concat([all.reset_index(drop=True), TrialNUM_df], axis=1)
all = pd.concat([all.reset_index(drop=True), img1_df], axis=1)
all = pd.concat([all.reset_index(drop=True), img2_df], axis=1)
all = pd.concat([all.reset_index(drop=True), Choice_RESP_df], axis=1)
all = pd.concat([all.reset_index(drop=True), Choice_RT_df], axis=1)

all

# %%
all.to_excel("f_209_1.xlsx")

# %%
# Out:
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3'] and [51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 69.0, 70.0, 71.0, 72.0, 73.0] and ['']
