# %%
#import necessary tools
import re
from string import digits
import pandas as pd
import numpy as np

# %%
#read the documents
with open('101.txt','rb') as f:
    contents = f.read()
    contents = contents.decode("utf-16").rstrip("\n")
    contents = contents.split("\r\n") #maybe need to strip \t?

# %%
BlockNum=[]
Procedure=list()
TrialNUM =[] #somehow eprime writes as TrialNUM
img1 =[]
img2=[]
Choice_RESP = []
Choice_RT=[]
#there should be a BL and LB version
#101 is BL


for i in range(len(contents)):
    
    
    if contents[i] == '\t*** LogFrame Start ***' and contents[i+4].startswith("\tTrial")==True:
        #all black trials
        Procedurea = contents[i+1].split("Procedure: ",1)[1] 
        Procedure.append(Procedurea)        
        
        img1a =contents[i+2].split("img1: ",1)[1] 
        img1.append(img1a)
        
        img2a =contents[i+3].split("img2: ",1)[1] 
        img2.append(img2a)
        
        TrialNUMa =[''.join(c for c in contents[i+4] if c in digits)]
        if TrialNUMa == ['']:
            TrialNUMa = ['1']
        else:
            TrialNUMa = [float(i)+1 for i in TrialNUMa] 
            TrialNUMa = list(TrialNUMa)
        TrialNUM=TrialNUM+TrialNUMa
        
        BlockNuma =['b1'.join(c for c in contents[i+5] if c in digits)]
        BlockNum=BlockNum+BlockNuma
        
        ChoiceB_RESPa =[''.join(c for c in contents[i+15] if c in digits)]
        ChoiceB_RESP=ChoiceB_RESP+ChoiceB_RESPa
        
        ChoiceB_RTa =[''.join(c for c in contents[i+14] if c in digits)]
        ChoiceB_RT=ChoiceB_RT+ChoiceB_RTa
        
    elif contents[i] == '\t*** LogFrame Start ***' and contents[i+5].startswith("\tTrial")==True:
        #second like
        Procedurea = contents[i+1].split("Procedure: ",1)[1] 
        Procedure.append(Procedurea)        
        
        img1a =contents[i+2].split("img1: ",1)[1] 
        img1.append(img1a)
        
        img2a =contents[i+3].split("img2: ",1)[1] 
        img2.append(img2a)
        
        TrialNUMa =[''.join(c for c in contents[i+5] if c in digits)]
        if TrialNUMa == ['']:
            TrialNUMa = ['51']
        else:
            TrialNUMa = [float(i)+1 for i in TrialNUMa] 
            TrialNUMa = list(TrialNUMa)
        TrialNUM=TrialNUM+TrialNUMa
        
        BlockNuma =['b2'.join(c for c in contents[i+6] if c in digits)]
        BlockNum=BlockNum+BlockNuma
        
        ChoiceB_RESPa =[''.join(c for c in contents[i+16] if c in digits)]
        ChoiceB_RESP=ChoiceB_RESP+ChoiceB_RESPa
        
        ChoiceB_RTa =[''.join(c for c in contents[i+15] if c in digits)]
        ChoiceB_RT=ChoiceB_RT+ChoiceB_RTa
        
    elif contents[i] == '\t*** LogFrame Start ***' and contents[i+6].startswith("\tTrial")==True:
        #first like
        Procedurea = contents[i+2].split("Procedure: ",1)[1] 
        Procedure.append(Procedurea)        
        
        img1a =contents[i+3].split("img1: ",1)[1] 
        img1.append(img1a)
        
        img2a =contents[i+4].split("img2: ",1)[1] 
        img2.append(img2a)
        
        TrialNUMa =[''.join(c for c in contents[i+6] if c in digits)]
        if TrialNUMa == None:
            TrialNUMa = ["1"]
        else:
            TrialNUMa = [float(i)+1 for i in TrialNUMa] 
            TrialNUMa = list(TrialNUMa)
        TrialNUM=TrialNUM+TrialNUMa
        #trial needs to be plus one, the NONE group is also not right yet
        #needs to be (blocknum-1)*50+trial
        
        BlockNuma =[''.join(c for c in contents[i+7] if c in digits)]
        BlockNum=BlockNum+BlockNuma
        
        Choice_RESPa =['b3'.join(c for c in contents[i+16] if c in digits)]
        Choice_RESP=Choice_RESP+Choice_RESPa
        
        Choice_RTa =[''.join(c for c in contents[i+15] if c in digits)]
        Choice_RT=Choice_RT+Choice_RTa

        
        
Procedure_df = pd.DataFrame(Procedure)
Procedure_df.columns = ['Btype']  
        
img1 = [int(i) for i in img1] 
img1_df = pd.DataFrame(img1)
img1_df.columns = ['img1']

img2 = [int(i) for i in img2] 
img2_df = pd.DataFrame(img2)
img2_df.columns = ['img2']

TrialNUM = [int(i) for i in TrialNUM] 
TrialNUM_df = pd.DataFrame(TrialNUM)
TrialNUM_df.columns = ['trial']

BlockNum = [int(i) for i in BlockNum] 
BlockNum_df = pd.DataFrame(BlockNum)
BlockNum_df.columns = ['block']

Choice_RESP = [int(i) for i in Choice_RESP] 
Choice_RESP_df = pd.DataFrame(Choice_RESP)
Choice_RESP_df.columns = ['RESP']

Choice_RT = [int(i) for i in Choice_RT] 
Choice_RT_df = pd.DataFrame(Choice_RT)
Choice_RT_df.columns = ['RT']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-de8d0e9c4478> in <module>
#      62         BlockNum=BlockNum+BlockNuma
#      63
# ---> 64         ChoiceB_RESPa =[''.join(c for c in contents[i+16] if c in digits)]
#      65         ChoiceB_RESP=ChoiceB_RESP+ChoiceB_RESPa
#      66
#
# IndexError: list index out of range

# %%
sub_id = contents[16].split("Subject: ",1)[1] 
sub_df = pd.DataFrame(np.repeat(sub_id, img1_df.shape[0], axis = 0))
sub_df.columns = ['sub']

all = pd.concat([sub_df.reset_index(drop=True), BlockNum_df], axis=1)
all = pd.concat([all.reset_index(drop=True), Procedure_df], axis=1)
all = pd.concat([all.reset_index(drop=True), TrialNUM_df], axis=1)
all = pd.concat([all.reset_index(drop=True), img1_df], axis=1)
all = pd.concat([all.reset_index(drop=True), img2_df], axis=1)
all = pd.concat([all.reset_index(drop=True), ChoiceB_RESP_df], axis=1)
all = pd.concat([all.reset_index(drop=True), ChoiceB_RT_df], axis=1)

all
# Out:
#      sub  block        Btype  trial  img1  img2  RESP    RT
# 0    101      2   ChooseLike     51   201   202     0  6400
# 1    101      2   ChooseLike      2   163   236     0     2
# 2    101      2   ChooseLike      3   190   201     0     1
# 3    101      2   ChooseLike      4   135   205     0     2
# 4    101      2   ChooseLike      5   139   212     0     1
# ..   ...    ...          ...    ...   ...   ...   ...   ...
# 97   101      3  ChooseBlack     97   124   223   616  6400
# 98   101      3  ChooseBlack     98   222   223   867  6400
# 99   101      3  ChooseBlack     99   161   173   925  6400
# 100  101      3  ChooseBlack    100   142   180  1934  6400
# 101  101      3  ChooseBlack    101   135   187  1473  6400
#
# [102 rows x 8 columns]

# %%
all.to_excel("f_209_2.xlsx")

# %%
new_all = all.assign(sep_trial = lambda x: x.trial+1)

#new_all.assign(real_trial = lambda x: x.sep_trial+1)

new_all['Flag'] = df.groupby('Product')['Index'].transform(lambda x: 'right' if sum(x)/len(x) == 1 else 'wrong')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-06e46db2c0d1> in <module>
# ----> 1 new_all = all.assign(sep_trial = lambda x: x.trial+1+block*30)
#       2
#       3 #new_all.assign(real_trial = lambda x: x.sep_trial+1)
#       4
#       5
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in assign(self, **kwargs)
#    3565
#    3566         for k, v in kwargs.items():
# -> 3567             data[k] = com.apply_if_callable(v, data)
#    3568         return data
#    3569
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     346
#     347     if callable(maybe_callable):
# --> 348         return maybe_callable(obj, **kwargs)
#     349
#     350     return maybe_callable
#
# <ipython-input-97-06e46db2c0d1> in <lambda>(x)
# ----> 1 new_all = all.assign(sep_trial = lambda x: x.trial+1+block*30)
#       2
#       3 #new_all.assign(real_trial = lambda x: x.sep_trial+1)
#       4
#       5
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#     498         lvalues = extract_array(left, extract_numpy=True)
#     499         rvalues = extract_array(right, extract_numpy=True)
# --> 500         result = arithmetic_op(lvalues, rvalues, op, str_rep)
#     501
#     502         return _construct_result(left, result, index=left.index, name=res_name)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op, str_rep)
#     195     else:
#     196         with np.errstate(all="ignore"):
# --> 197             res_values = na_arithmetic_op(lvalues, rvalues, op, str_rep)
#     198
#     199     return res_values
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     147
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#     151         result = masked_arith_op(left, right, op)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     206     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#     210
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#     123     return result
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# ValueError: operands could not be broadcast together with shapes (204,) (0,)

# %%
temp_a = all
            
'''
clean <- testing %>%
  mutate(sep_trial = 
           ifelse(!is.na(trial), as.numeric(trial) +1, 
           ifelse(block < 2.5, 1, 51)),  #depends on block num too
         real_trial = 
           ifelse(block < 1.5, sep_trial, 
           ifelse(block < 2.5, sep_trial + 51, 
           ifelse(block < 3.5, sep_trial + 52, sep_trial+103)))
         ) %>%
  select(sub, block, Btype, real_trial, img1, img2, RESP, RT)
'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-121-3177bb536b62> in <module>
#       2
#       3 for row in temp_a.iterrows():
# ----> 4     row += 1
#       5     print(row)
#       6
#
# TypeError: can only concatenate tuple (not "int") to tuple
