# %%
with open("/Users/xiaoma/Documents/PVDM_master/fmri_txt/102_short.txt", encoding="utf8", errors='ignore') as f:
    lines = f.readlines()
    
    #remove the headlines and bottom lines
    #treat each block
    #create output format
    for line3 in lines:
        print(line3)
# Out:
# *** Header Start ***
#
#
#
# VersionPersist: 1
#
#
#
# LevelName: Session
#
#
#
# LevelName: Block
#
#
#
# LevelName: Trial
#
#
#
# LevelName: SubTrial
#
#
#
# LevelName: LogLevel5
#
#
#
# LevelName: LogLevel6
#
#
#
# LevelName: LogLevel7
#
#
#
# LevelName: LogLevel8
#
#
#
# LevelName: LogLevel9
#
#
#
# LevelName: LogLevel10
#
#
#
# Experiment: PVDM_BL_fMRI
#
#
#
# SessionDate: 11-19-2018
#
#
#
# SessionTime: 14:29:28
#
#
#
# SessionStartDateTimeUtc: 11/19/2018 7:29:28 PM
#
#
#
# Subject: 102
#
#
#
# Session: 1
#
#
#
# DataFile.Basename: PVDM_BL_fMRI-102-1
#
#
#
# RandomSeed: 1365458218
#
#
#
# Group: 1
#
#
#
# Display.RefreshRate: 60.003
#
#
#
# *** Header End ***
#
#
#
# 	Level: 2
#
#
#
# 	*** LogFrame Start ***
#
#
#
# 	Procedure: assignPAR
#
#
#
# 	ListAssign: 1
#
#
#
# 	jitter: 4800
#
#
#
# 	num: 0
#
#
#
# 	imgL1: 189
#
#
#
# 	imgL2: 191
#
#
#
# 	diffL: 4
#
#
#
# 	imgB1: 131
#
#
#
# 	imgB2: 195
#
#
#
# 	diffB: 4
#
#
#
# 	ListAssign.Cycle: 1
#
#
#
# 	ListAssign.Sample: 1
#
#
#
# ...
